# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Rostislav Tsonev**
#
# Fulltime dad, part time software dev

# %% [markdown]
# *I am interested in data science because I like learning new things and would like to work as a Data Engineer one day.*

# %% [markdown]
# ### Calclulates if number is even

# %%
def isEven(numer):
    return numer % 2 == 0;

print("Is 4 even? " + str(isEven(4)));
print("Is 5 even? " + str(isEven(5)));
# Out:
# Is 4 even? True
# Is 5 even? False

# %% [markdown]
# * first point
# * second point
# * third point
#
# 1. numbered point one
#    1. nested numbered point
# 2. numbered point two
#
# | Syntax      | Description | Test Text     |
# | :---        |    :----:   |          ---: |
# | Header      | Title       | Here's this   |
# | Paragraph   | Text        | And more      |
#
# ~~The End~~
